# %% [markdown]
# # Johanes Andrian Kartono 03729894
#
# ## Verification

# %% [markdown]
# #### Task 4.2.1: Auto Correlation

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import simstudy4

simstudy4.task_4_2_1()
# Out:
# Name: autocorr 1
# Lag = 0; covariance = 25.0; correlation = 0.99995
# Lag = 1; covariance = -25.0; correlation = -0.99995
# Name: autocorr 2
# Lag = 0; covariance = 14.75; correlation = 0.99995
# Lag = 1; covariance = -12.25; correlation = -0.8304669491525424
# Lag = 2; covariance = 9.75; correlation = 0.6609838983050847
# Lag = 3; covariance = -12.25; correlation = -0.8304669491525424

# %% [markdown]
# ## Simulation Study
#
# #### Task 4.3.1: Correlations in the DES
#
# Calculate the above correlations and autocorrelations for a system with a single server with the
# service rate µ = 0.015 and two users, the arrival rate of which is varied such that the offered
# traffic is varied in the list A = 0.01,0.5,0.8,0.95. The queue size should be infinite (you can set
# it to 10000) and the simulation time should be 10000 seconds. Use the implemented heatmap
# to visualize correlations.

# %%
# separated as 4 separate function calls to prevent output being too long per code block
simstudy4.task_4_3_1(0.01)
# Out:
# simulation with offered traffic of 0.01
# Name: accumulated iat with lags 1 to 10
# Lag = 0; covariance = 40760140.48804856; correlation = 0.9993377483443708
# Lag = 1; covariance = 654000.9984159917; correlation = 0.016034485586811035
# Lag = 2; covariance = 688887.9811454266; correlation = 0.0168898280451518
# Lag = 3; covariance = -960955.3844211698; correlation = -0.023560247306027564
# Lag = 4; covariance = -372176.3520258367; correlation = -0.009124842877555257
# Lag = 5; covariance = 117772.39052391797; correlation = 0.002887487485422572
# Lag = 6; covariance = 568383.904461503; correlation = 0.013935366377019434
# Lag = 7; covariance = -972818.1060015708; correlation = -0.023851091874555735
# Lag = 8; covariance = 407804.2040075585; correlation = 0.009998349616036694
# Lag = 9; covariance = 818200.9303121641; correlation = 0.020060261461345468
# Lag = 10; covariance = -1979043.773499526; correlation = -0.04852125446093255
# Name: waiting time with lags 1 to 20
# ...

# %%
simstudy4.task_4_3_1(0.5)
# Out:
# simulation with offered traffic of 0.5
# Name: accumulated iat with lags 1 to 10
# Lag = 0; covariance = 17918.22502581326; correlation = 0.9999866243997699
# Lag = 1; covariance = -60.61691756765504; correlation = -0.0033829303233257764
# Lag = 2; covariance = 38.59188609240664; correlation = 0.0021537495955749435
# Lag = 3; covariance = 24.278397041442076; correlation = 0.001354937348332978
# Lag = 4; covariance = -85.81887748740337; correlation = -0.0047894101946356635
# Lag = 5; covariance = 36.07525215179703; correlation = 0.0020133004006633584
# Lag = 6; covariance = -61.194951794241206; correlation = -0.0034151894613932317
# Lag = 7; covariance = 77.39136624313687; correlation = 0.004319084673603054
# Lag = 8; covariance = 45.98224678991755; correlation = 0.0025661934529522313
# Lag = 9; covariance = 105.00085768029021; correlation = 0.00585992491329528
# Lag = 10; covariance = -15.482015474844957; correlation = -0.0008640257822017464
# Name: waiting time with lags 1 to 20
# ...

# %%
simstudy4.task_4_3_1(0.8)
# Out:
# simulation with offered traffic of 0.8
# Name: accumulated iat with lags 1 to 10
# Lag = 0; covariance = 6962.729260216061; correlation = 0.9999916958695254
# Lag = 1; covariance = 11.270346918101495; correlation = 0.001618654539975674
# Lag = 2; covariance = -13.80194713828223; correlation = -0.0019822446068632725
# Lag = 3; covariance = 46.79729168154154; correlation = 0.0067210574074904345
# Lag = 4; covariance = -11.94758761133562; correlation = -0.0017159202879358396
# Lag = 5; covariance = -6.2168139633431565; correlation = -0.0008928628567579771
# Lag = 6; covariance = -1.29888157766527; correlation = -0.0001865462152901336
# Lag = 7; covariance = -35.427609089669204; correlation = -0.005088136213568868
# Lag = 8; covariance = -7.563846126877252; correlation = -0.001086324490445204
# Lag = 9; covariance = -14.333424748822836; correlation = -0.002058575766271974
# Lag = 10; covariance = 7.699556861998644; correlation = 0.001105815354313366
# ...

# %%
simstudy4.task_4_3_1(0.95)
# Out:
# simulation with offered traffic of 0.95
# Name: accumulated iat with lags 1 to 10
# Lag = 0; covariance = 4964.271992240806; correlation = 0.9999929671071606
# Lag = 1; covariance = -10.550115137328248; correlation = -0.0021251939772818323
# Lag = 2; covariance = -1.177705923603753; correlation = -0.00023723471291761333
# Lag = 3; covariance = -4.215019846188625; correlation = -0.0008490651215311715
# Lag = 4; covariance = -19.69081644805192; correlation = -0.00396647846762357
# Lag = 5; covariance = 16.573290097763675; correlation = 0.003338490228878356
# Lag = 6; covariance = 0.41341674428440456; correlation = 8.327783759933236e-05
# Lag = 7; covariance = -0.9105736924457233; correlation = -0.0001834241334684613
# Lag = 8; covariance = -4.676928942225459; correlation = -0.0009421111609507726
# Lag = 9; covariance = 32.440872708091774; correlation = 0.006534824160645381
# Lag = 10; covariance = 10.998305958013589; correlation = 0.0022154766349016903
# ...

# %% [markdown]
# #### Task 4.3.2 The Visualization of Covariance/Correlation
# Reuse the scenario parameters of the previous task. Now, we want to have a more direct visualization of the relationship between the following values.
# - IAT and serving time of a packet
# - serving time and system time of a packet <br>
#
# Please draw scatter plots with different As. In order to retrieve the values, you might have to
# get access to the inner variables of StatisticCollection. You should have eight plots in total.

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15,10]
simstudy4.task_4_3_2(0.01)
# Out:
# simulation with offered traffic of 0.01

# %%
simstudy4.task_4_3_2(0.5)
# Out:
# simulation with offered traffic of 0.5

# %%
simstudy4.task_4_3_2(0.8)
# Out:
# simulation with offered traffic of 0.8

# %%
simstudy4.task_4_3_2(0.95)
# Out:
# simulation with offered traffic of 0.95

# %% [markdown]
# #### Task 4.3.3: Auto Relation of Waiting Times
#
# Prepare two plots for the autocorrelation for lags ranging from 1 to 20 and a given offered
# traffic of A = 0.01,0.5,0.8,0.95. One plot should be for N = 100 and the other one - for N
# = 10000, where N is the number of served packets in one simulation run. In other words, the
# packets that are dropped will not be considered. The queue size should be unlimited. Hint: For
# this, you have to implement the function do_simulation_n_limit() in class Simulation, such
# that the simulation stops after a total packet count of N. However, you can take most of the
# code from your regular simulation routine.

# %%
simstudy4.task_4_3_3(100)
# Out:
# simulation with offered traffic of 0.01
# simulation with offered traffic of 0.5
# simulation with offered traffic of 0.8
# simulation with offered traffic of 0.95

# %%
simstudy4.task_4_3_3(1000)
# Out:
# simulation with offered traffic of 0.01
# simulation with offered traffic of 0.5
# simulation with offered traffic of 0.8
# simulation with offered traffic of 0.95

# %% [markdown]
# ## Analysis and General Questions
#
# #### Task 4.4.1: Lag size
#
# What are reasonable lag sizes for the test sequences in task 4.2.1? What does the correlation
# coefficient say? Consider especially the extreme values!

# %% [markdown]
# Basically, reasonable lag sizes are lags that will not output the same result because the sequence is periodic (repeat itself after a certain lag).
# Therefore, for the first sequence the reasonable lags are 0 and 1 while for the second series, lag sizes between 0 until 3 are reasonable

# %% [markdown]
# #### Task 4.4.2: Correlation Times in the DES
# What conclusions can you draw from the correlation coefficients? Interpret all results of task
# 4.3.1. What can you say about whether packets have to wait or not? Explain!

# %% [markdown]
# IAT and WT:
# negative and very small to zero for all values of offered traffic. This means that they if IAT is short, packets are more likely to wait longer
#
# IAT and Service Time:
# value really close to 0 (can be either positive or negative) -> no correlation. This can be explained as both values are generated by separate RNS generators.
#
# IAT and System time:
# The values show similar behavior to the correlation value of IAT and WT, which makes sense because system time is a combination of service time and waiting time (plus service time is uncorrelated with IAT). This means that shorter IAT means higher system time.
#
# Service time and system time
# The values show higher correlation rate for low offered traffic (close to 1) and lower correlation for higher offered traffic. This is related to the previous point where system time is a combination of waiting time and service time. In the case of low offered traffic, the waiting time is not so high and therefore the value of system time is roughly equal to service time. This is not true for higher utilization because waiting time is now not close to 0.
#
# WT1 and WT2
# The waiting time of both users show a value close to 0 meaning that they are not correlated to one another for low offered traffic. However the value slowly increase as the offered traffic increase. This can be explained because if a user is waiting it means a user that will arrive will have to wait as well. This is however not apparent for low offered traffic as there is almost no waiting time or the waiting time is too short to show a correlation. (if value of wt1 increase, wt2 will also increase)

# %% [markdown]
# #### Task 4.4.3: Visualization of Covariance/Correlation
# What information can you obtain from the scatter plots you draw in task 4.3.2? How does the
# information relate to the covariance/correlation values in task 4.3.1?

# %% [markdown]
# Values that have a high correlation seems to show a straight line in their graph (visible from service vs system time). In comparison, variables that do not correlate seems to show no particular distribution/ looks random (iat vs st). Positive correlation is also shown here as the straight line is going towards the upper right.

# %% [markdown]
# #### Task 4.4.4: Auto Correlation
#
# After checking the result of task 4.3.3, what conclusions could you draw when you compare
# N = 100 and N = 10000? What is the problem with N = 100?

# %% [markdown]
# It looks like the system is not stable in this phase as can be shown if we execute the run multiple times. This can likely be related to the fact that the system is still in the transient phase for N=100 (for example 0.8 can show correlation value higher than 0.9 and vice versa between two different runs) and will therefore show "random" results compared to the stable phase for N=10000 packets
